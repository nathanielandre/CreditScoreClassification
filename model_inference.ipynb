# %%
# Import Library

import pickle
import pandas as pd
import numpy as np

# %%
with open('model_xgbc_grid.pkl', 'rb') as file_1:
  model_xgbc = pickle.load(file_1)

# %%
model_xgbc
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipe_num',
#                                                   Pipeline(steps=[('minmaxscaler',
#                                                                    MinMaxScaler())]),
#                                                   ['Age', 'Annual_Income',
#                                                    'Monthly_Inhand_Salary',
#                                                    'Num_Bank_Accounts',
#                                                    'Num_Credit_Card',
#                                                    'Interest_Rate',
#                                                    'Num_of_Loan',
#                                                    'Delay_from_due_date',
#                                                    'Num_of_Delayed_Payment',
#                                                    'Changed_Credit_Limit',
# ...

# %%
data = {
    'ID':[1234],
    'Customer_ID': [1234],
    'Month': ['May'],
    'Name': ['Nanananan'],
    'Age': [43],
    'SSN': ['dafafa'],
    'Occupation': ['Doctor'],
    'Annual_Income': [32119.36],
    'Monthly_Inhand_Salary': [2688.613333],
    'Num_Bank_Accounts': [3],
    'Num_Credit_Card': [5],
    'Interest_Rate': [12],
    'Num_of_Loan': [7],
    'Type_of_Loan': ['Not Specified, Payday Loan, Not Specified, Credit-Builder Loan, Debt Consolidation Loan'],
    'Delay_from_due_date': [0],
    'Num_of_Delayed_Payment': ['0'],
    'Changed_Credit_Limit': ['10.0'], 
    'Num_Credit_Inquiries': [4.0],
    'Credit_Mix': ['Standard'],
    'Outstanding_Debt': [999.25],
    'Credit_Utilization_Ratio': [37.593211],
    'Credit_History_Age': ['127.0'],  # Could be a number (years of credit history)
    'Payment_of_Min_Amount': ['Yes'],
    'Total_EMI_per_month': [109.344652],
    'Amount_invested_monthly': [105.316493],
    'Payment_Behaviour': ['High_spent_Medium_value_payments'],
    'Monthly_Balance': [304.200188]
}

data_inf = pd.DataFrame.from_dict(data)
data_inf
# Out:
#      ID  Customer_ID Month       Name  Age     SSN Occupation  Annual_Income  \
# 0  1234         1234   May  Nanananan   43  dafafa     Doctor       32119.36
#
#    Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Num_Credit_Inquiries  \
# 0            2688.613333                  3  ...                   4.0
#
#    Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  Credit_History_Age  \
# 0    Standard            999.25                37.593211               127.0
#
#   Payment_of_Min_Amount Total_EMI_per_month  Amount_invested_monthly  \
# 0                   Yes          109.344652               105.316493
#
#                   Payment_Behaviour  Monthly_Balance
# 0  High_spent_Medium_value_payments       304.200188
#
# [1 rows x 27 columns]

# %%
y_pred_inf = model_xgbc.predict(data_inf)
y_pred_inf
# Out:
# array([2])
